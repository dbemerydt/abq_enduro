# %%
import numpy as np
import pandas as pd

# %%
raw_results = pd.read_csv('example_input.csv')
raw_results
# Out:
#      name  number stage_1_start stage_1_finish  stage_1_time stage_2_start  \
# 0     ben     314         00:00           7:43           NaN         00:00
# 1    davi     420         00:30           8:00           NaN         00:30
# 2  jeremy     666         01:00           8:05           NaN         01:00
#
#   stage_2_finish  stage_2_time stage_3_start stage_3_finish  stage_3_time  \
# 0           3:13           NaN         00:00          12:32           NaN
# 1           3:31           NaN         00:30          12:59           NaN
# 2           3:43           NaN         01:00          13:10           NaN
#
#    total_time  place
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN

# %%
num_stages = 3
df = raw_results.copy()
for i in range(1,num_stages+1):
    df['stage_'+str(i)+'_start'] = pd.to_datetime(df['stage_'+str(i)+'_start'],format='%M:%S')
    df['stage_'+str(i)+'_finish'] = pd.to_datetime(df['stage_'+str(i)+'_finish'],format='%M:%S')

# %%
for i in range(1,num_stages+1):
    df['stage_'+str(i)+'_time'] = df['stage_'+str(i)+'_finish'] - df['stage_'+str(i)+'_start']

# %%
df['total_time'] = df[['stage_'+str(i)+'_time' for i in range(1,num_stages+1)]].sum(axis=1)

# %%
df['rank'] = df['total_time'].rank(ascending=True)

# %%
df
# Out:
#      name  number       stage_1_start      stage_1_finish stage_1_time  \
# 0     ben     314 1900-01-01 00:00:00 1900-01-01 00:07:43     00:07:43
# 1    davi     420 1900-01-01 00:00:30 1900-01-01 00:08:00     00:07:30
# 2  jeremy     666 1900-01-01 00:01:00 1900-01-01 00:08:05     00:07:05
#
#         stage_2_start      stage_2_finish stage_2_time       stage_3_start  \
# 0 1900-01-01 00:00:00 1900-01-01 00:03:13     00:03:13 1900-01-01 00:00:00
# 1 1900-01-01 00:00:30 1900-01-01 00:03:31     00:03:01 1900-01-01 00:00:30
# 2 1900-01-01 00:01:00 1900-01-01 00:03:43     00:02:43 1900-01-01 00:01:00
#
#        stage_3_finish stage_3_time total_time  place  rank
# 0 1900-01-01 00:12:32     00:12:32   00:23:28    NaN   3.0
# 1 1900-01-01 00:12:59     00:12:29   00:23:00    NaN   2.0
# 2 1900-01-01 00:13:10     00:12:10   00:21:58    NaN   1.0
